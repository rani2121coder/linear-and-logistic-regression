# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Sandhya\Downloads\Iris.xls")
df.head()
df['species'] = iris.target

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species', 'species'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['SepalLengthCm'], df['SepalWidthCm'], marker='+', color='red')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Iris Dataset - Sepal Length vs Sepal Width')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['PetalLengthCm'], df['PetalWidthCm'], marker='+', color='blue')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Iris Dataset - Petal Length vs Petal Width')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['SepalLengthCm'], df['PetalLengthCm'], marker='+', color='green')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.title('Iris Dataset - Sepal Length vs Petal Length')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['SepalWidthCm'], df['PetalWidthCm'], marker='+', color='yellow')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Iris Dataset - Sepal Width vs Petal Width')
plt.show()

# %%
x = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=23)

# %%
logreg = LogisticRegression(max_iter=1000)

# %%
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = logreg.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        12
# Iris-versicolor       1.00      1.00      1.00         8
#  Iris-virginica       1.00      1.00      1.00        10
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# Confusion Matrix:
# [[12  0  0]
#  [ 0  8  0]
#  [ 0  0 10]]
